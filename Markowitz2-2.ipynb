# %%
#cellule technique
! pip install yfinance pandas

import yfinance as yf
import pandas as pd
from io import StringIO
import requests
import matplotlib.pyplot as plt
import numpy as np

def get_sp500_returns():
    # 1. Récupération de la liste des tickers du S&P 500 via Wikipédia
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

    # Ajout d'un User-Agent pour éviter le blocage 403 Forbidden
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
    response = requests.get(url, headers=headers)
    response.raise_for_status() # Lève une exception pour les codes d'état d'erreur

    table = pd.read_html(StringIO(response.text))
    df_tickers = table[0]
    tickers = df_tickers['Symbol'].tolist()

    # Correction pour les tickers contenant des points (ex: BRK.B -> BRK-B pour Yahoo Finance)
    tickers = [t.replace('.', '-') for t in tickers]

    print(f"Téléchargement des données pour {len(tickers)} entreprises...")
    return (tickers)

liste= get_sp500_returns()
tickers = liste[0:20]
# Out:
# Requirement already satisfied: yfinance in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: pandas in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: requests>=2.31 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (2.34.2)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (2026.2)
# Requirement already satisfied: peewee>=3.16.2 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (4.0.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.15 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (7.35.0)
# Requirement already satisfied: websockets>=13.0 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from yfinance) (16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from curl_cffi>=0.15->yfinance) (2026.5.20)
# Requirement already satisfied: rich in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from rich->curl_cffi>=0.15->yfinance) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/allysa/anaconda3/envs/sd/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)
# Téléchargement des données pour 503 entreprises...

# %%
# fonction pour visualiser
def visualise(ticker):
  fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1, figsize=(12, 15))

  #courbe des prix
  data= yf.download(ticker, start="2025-01-01", end="2026-01-01")["Close"]

  ax1.plot(data, label='Prix de clôture (MMM)', color='blue')
  ax1.set_title('Évolution du prix de clôture de MMM (2025)')
  ax1.set_xlabel('Date')
  ax1.set_ylabel('Prix de clôture (USD)')
  ax1.grid(True, linestyle='--', alpha=0.7)
  ax1.legend()

  #rendements
  returns= data.pct_change()[1:]
  # Tracer la courbe
  ax2.plot(returns, label='Rendement journalier (MMM)', color='red')
  ax2.set_title('Évolution du rendement de MMM (2025)')
  ax2.set_xlabel('Date')
  ax2.set_ylabel('Rendement en % ')
  ax2.grid(True, linestyle='--', alpha=0.7)
  ax2.legend()

  # Tracer l'histogramme (graph3)
  ax3.hist(returns, bins=30, color='skyblue', edgecolor='black', alpha=0.7, label='Rendements quotidiens')

  # Ajouter des lignes pour la moyenne et l'écart-type
  moyenne = returns.mean()
  ecart_type = returns.std()
  ax3.axvline(moyenne.iloc[0], color='red', linestyle='--', label=f'Moyenne : {moyenne.iloc[0]:.2f}%')
  ax3.axvline(moyenne.iloc[0] + ecart_type.iloc[0], color='green', linestyle=':', label=f'+1σ : {(moyenne + ecart_type).iloc[0]:.2f}%')
  ax3.axvline(moyenne.iloc[0] - ecart_type.iloc[0], color='green', linestyle=':', label=f'-1σ : {(moyenne - ecart_type).iloc[0]:.2f}%')

  #ajouter une gaussienne
  X=np.linspace(moyenne-5*ecart_type,moyenne+5*ecart_type,100)
  def f(x):
    return 1.6/(ecart_type.iloc[0]*np.sqrt(2*np.pi))*np.exp(-(x-moyenne.iloc[0])**2/(2*ecart_type.iloc[0]**2))
  ax3.plot(X,f(X),color='black',label='Gaussienne')

  # Personnalisation
  ax3.set_title('Histogramme des rendements quotidiens de MMM (2025)')
  ax3.set_xlabel('Rendement quotidien (%)')
  ax3.set_ylabel('Fréquence')
  ax3.grid(True, linestyle='--', alpha=0.5)
  ax3.legend()

  #plt.tight_layout() # Adjust layout to prevent overlapping
  plt.show()

# %%
# pour obtenir la matrice des rendements et de covariance

def parametre(tickers):
  data= yf.download(tickers, start="2025-01-01", end="2026-01-01")["Close"]
  returns=data.pct_change().dropna()
  r=returns.mean()
  cov=returns.cov()
  return np.array(r*100),np.array(cov*10000)

# %%
# permet de trouver le portefeuille optimal

from scipy.linalg import pinv

def inv(A):
    try:
        return np.linalg.inv(A)
    except np.linalg.LinAlgError:
        return pinv(A)

#calcul le protefeuille de rendement optimal en fixant la variance a c
def optimal1(R, V, c):
    R = np.asarray(R).flatten()  # Convertir R en vecteur 1D
    V_inv = inv(V)
    P = np.dot(R, np.dot(V_inv, R))  # R^T V^{-1} R
    w = np.dot(V_inv, R) * np.sqrt(c / P)
    return w

#calcul le protefeuille de variance minimale en fixant le rendement a mu
def optimal2(R, V, mu):
    R = np.asarray(R).flatten()  # Convertir R en vecteur 1D
    V_inv = inv(V)
    one=np.ones(len(R))
    a = np.dot(R, np.dot(V_inv,R))
    b = np.dot(one, np.dot(V_inv,R))
    c = np.dot(R, np.dot(V_inv,one))
    d = np.dot(one, np.dot(V_inv,one))
    M=inv([[a,b],[c,d]])
    w=(mu*M[0][0]+M[0][1])*np.dot(R,V_inv)+(mu*M[1][0]+M[1][1])*np.dot(one,V_inv)
    return w

# %%
print("le portefeuille opti pour",tickers)
R,V=parametre(tickers)
one=np.ones(len(R))
c=2
w1=optimal1(R,V,c)
mu1=np.dot(w1,R)
s1=np.dot(w1,np.dot(V,w1))
w2=optimal2(R,V,mu1)
mu2=np.dot(w2,R)
s2=np.dot(w2,np.dot(V,w2))
print("rendement(1,2)=",mu1,"-",mu2,"/")
print("variance=",s1,"-",s2,"/")
print("norm1=",np.dot(w1,one),"-",np.dot(w2,one),"/")
print("norm=",np.dot(w1-w2,w1-w2))
# Out:
# le portefeuille opti pour ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL']
# /tmp/ipykernel_1326/1412144060.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data= yf.download(tickers, start="2025-01-01", end="2026-01-01")["Close"]
# [*********************100%***********************]  20 of 20 completed
# rendement(1,2)= 0.39214863283916557 - 0.3921486328391656 /
# variance= 2.0000000000000004 - 2.1617535547873463 /
# norm1= 0.5500780359750491 - 0.9999999999999998 /
# norm= 0.060697986104432666

# %% [markdown]
# En **théorie moderne du portefeuille (MPT)**, l'objectif est de construire un portefeuille qui :
# - **Maximise le rendement espéré** pour un niveau de risque donné, **ou**
# - **Minimise le risque** pour un rendement espéré donné.
#
# Cependant, une **contrainte fondamentale** doit être respectée :
# > **La somme des poids des actifs dans le portefeuille doit être égale à 1** :
# > \[
# > \sum_{i=1}^{n} w_i = 1
# > \]
# Cette contrainte garantit que **100% du capital est alloué** aux actifs (pas de poids négatifs ou supérieurs à 1, sauf si on autorise la vente à découvert).
#
#
#
# #### **1. `optimal1` : Une solution incomplète**
# La fonction `optimal1` calcule un portefeuille qui maximise le rendement pour une variance donnée, **mais elle n'impose pas explicitement** que la somme des poids \( \sum w_i = 1 \).
# - **Problème** : Les poids retournés peuvent ne pas sommer à 1, ce qui signifie que le portefeuille n'est pas **pleinement investi** (ou pire, qu'il y a des poids négatifs ou > 1 sans contrôle).
# - **Conséquence** : Le portefeuille peut être **non réaliste** ou **non interprétable** en pratique.
#
# ---
#
# #### **2. `optimal2` : Une solution conforme à Markowitz**
# La fonction `optimal2` résout le **vrai problème de Markowitz** :
# \[
# \min_w w^T V w \quad \text{ sous les contraintes } \quad
# \begin{cases}
# w^T R = \mu \quad \text{(rendement espéré fixé)} \\
# \sum_{i=1}^n w_i = 1 \quad \text{(somme des poids = 1)}
# \end{cases}
# \]
# - **Avantage** :
#   - La solution **garantit** que le portefeuille est **pleinement alloué** (\( \sum w_i = 1 \)).
#   - Elle est **mathématiquement exacte** pour le problème standard de la frontière efficiente.
#   - Elle permet de **tracer la frontière efficiente complète** en faisant varier \( \mu \).
#
# ---
# ### **📊 Illustration**
# Pour construire la **frontière efficiente**, on utilise généralement `optimal2` en faisant varier \( \mu \) :
# 1. Pour chaque valeur de \( \mu \) (ex : de 0.05 à 0.20 par pas de 0.01) :
#    - Calculer \( w \) avec `optimal2(R, V, mu)`.
#    - Calculer le risque \( \sigma = \sqrt{w^T V w} \).
# 2. Tracer \( \sigma \) (risque) en fonction de \( \mu \) (rendement).
#
# **→ Résultat** : Une courbe qui représente **tous les portefeuilles optimaux**, avec la garantie que \( \sum w_i = 1 \).
#
#
# ---
# ### **💡 Conclusion**
# > **`optimal2` est la fonction qui répond le mieux au problème de Markowitz**, car elle :
# > - **Minimise le risque pour un rendement donné**.
# > - **Impose \( \sum w_i = 1 \)**, garantissant un portefeuille **valide et réaliste**.
# > - Permet de **construire la frontière efficiente complète**.
#
# **→ Pour une implémentation robuste de la MPT, privilégiez `optimal2` !**

# %% [markdown]
# On va tracer la frontiére efficiente par une methode de monte carlo

# %%
def tirage_MC(tickers,N,pos):
  n=len(tickers)
  l=-1
  if pos:
    l=0
  w_tirage=[]
  R_w=[]
  S_w=[]
  R,V=parametre(tickers)
  for k in range(N):
    w=np.random.uniform(low=l, high=1, size=n)
    w=w/np.sum(w)
    w_tirage.append(w)
    S_w.append(np.sqrt(np.dot(w,np.dot(V,w))))
    R_w.append(np.dot(w,R))
  R_w=np.array(R_w)
  S_w=np.array(S_w)
  return R_w,S_w,np.array(w_tirage)




def frontiere_MC(tickers,N,pos):
  R,S,w=tirage_MC(tickers,N,pos)
  n=len(tickers)
  idx=np.argsort(S)
  efficient_idx = [idx[0]]
  w_cible=[]
  for i in range(1, len(idx)):
        current_risk = S[idx[i]]
        current_return = R[idx[i]]
        last_efficient_return = R[efficient_idx[-1]]

        # Si le rendement est supérieur au dernier portefeuille efficace, il est efficace
        if current_return > last_efficient_return:
            efficient_idx.append(idx[i])
            if 0.75<R[idx[i]]<0.85:
              w_cible.append((w[idx[i]],R[idx[i]],S[idx[i]]))

  return S[efficient_idx], R[efficient_idx],S,R,w_cible


X,Y,X1,Y1,w=frontiere_MC(tickers,100000,False)
plt.ylim(-4, 4)  # Fixe les limites de l'axe X
plt.xlim(-5, 20)  # Fixe les limites de l'axe Y
plt.scatter(X1,Y1, c='green')
plt.scatter(X,Y, c='red')

plt.plot()
# Out:
# /tmp/ipykernel_1326/1412144060.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data= yf.download(tickers, start="2025-01-01", end="2026-01-01")["Close"]
# [*********************100%***********************]  20 of 20 completed
# []

# %%
def trace_opti(X):
  s=[]
  mu=[]
  for x in X:
    w2=optimal2(R,V,x)
    mu2=np.dot(w2,R)
    s2=np.sqrt(np.dot(w2,np.dot(V,w2)))
    mu.append(mu2)
    s.append(s2)
  return(np.array(s),np.array(mu))

# %%
R,V=parametre(tickers)
mu=np.linspace(0,2,100)
s2,mu2=trace_opti(mu)
plt.ylim(-2, 2)  # Fixe les limites de l'axe X
plt.xlim(0, 10)  # Fixe les limites de l'axe Y
plt.scatter(X1,Y1, c='green')
plt.scatter(X,Y, c='red',label='Frontiere efficiente MC')
plt.scatter(s2, mu2, color='gold', s=10,label='Frontiere efficiente calcul')
plt.axhline(y=0.8, color='b', linestyle='--', linewidth=2, label='Ligne de seuil')
plt.legend()
plt.plot()
# Out:
# /tmp/ipykernel_1326/1412144060.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data= yf.download(tickers, start="2025-01-01", end="2026-01-01")["Close"]
# [*********************100%***********************]  20 of 20 completed
# []

# %%
from importlib import reload
import backtest as bt

bt = reload(bt)

# Donnees
if "tickers" in globals() and len(tickers) > 0:
    bt_tickers = list(tickers)
else:
    bt_tickers = ["AAPL", "MSFT", "NVDA", "AMZN", "GOOGL", "META", "JPM", "XOM", "JNJ"]

raw = yf.download(bt_tickers, start="2024-01-01", end="2026-01-01", auto_adjust=True, progress=False)
prices_bt = raw["Close"] if hasattr(raw.columns, "levels") else (raw[["Close"]] if "Close" in raw.columns else raw)
if isinstance(prices_bt, pd.Series):
    prices_bt = prices_bt.to_frame()
prices_bt = prices_bt.dropna(axis=1, how="all")

def solve_markowitz_from_train(train_returns: pd.DataFrame):
    mu = train_returns.mean().values * 100.0
    sigma = train_returns.cov().values * 10000.0
    target = float(np.mean(mu))
    w = np.asarray(optimal2(mu, sigma, target)).flatten()
    w = np.clip(w, 0, None)
    s = w.sum()
    return np.ones_like(w) / len(w) if np.isclose(s, 0.0) else w / s

wf_cfg = bt.WalkForwardBacktestConfig(
    estimation_window=60,
    holding_period=5,
    transaction_cost_bps=10.0,
    long_only=True,
    frequency="daily",
    fallback="equal_weight",
)

res_bt = bt.walk_forward_backtest(
    prices=prices_bt,
    optimize_weights_fn=solve_markowitz_from_train,
    backtest_config=wf_cfg,
    label="Markowitz via backtest.py (minimal)",
)

print(res_bt.metrics.round(3).to_string())
bt.plot_backtest_nav({"Markowitz": res_bt}); plt.grid(alpha=0.3); plt.show()
# Out:
# Total return (%)                34.028
# CAGR (%)                        18.218
# Vol annualized (%)              14.249
# Sharpe                           1.279
# Max drawdown (%)               -12.909
# Benchmark total return (%)      56.745
# Benchmark CAGR (%)              29.282
# Benchmark vol annualized (%)    18.806
# Tracking error (%)              10.297
# Average turnover                 0.062
# Rebalance count                 89.000
